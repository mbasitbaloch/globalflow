# %%
import json

# %%
with open ('./fetched_data/fetched_4c6a18f3441e429da06f0783ea872882.json', 'r',encoding='utf-8') as access_json:
    read_content= json.load(access_json)

# %%
type(read_content)
# Out:
# dict

# %%
read_content
# Out:
# {'message': 'Store data fetched successfully.',
#  'success': True,
#  'user': {'_id': '68adf0a8a2e59d75c778fe54',
#   'firstName': 'ezill',
#   'lastName': 'zille',
#   'email': 'ezill512@gmail.com',
#   'industry': 'education',
#   'firebaseUid': '62klgCsYHJSJ5bx8u1MOiQDhYZ92',
#   'role': 'customer',
#   'ownerId': None,
#   'expertLanguages': [],
#   'expertiseLevel': 'intermediate',
#   'invitedBy': None,
#   'invitationStatus': 'pending',
#   'shopifyState': None,
#   'shopifyStores': [{'assignedExpertId': None,
#     'shopDomain': 'globalflow-ai-esp.myshopify.com',
#     'accessToken': 'shpua_442d55019ffd4e03da1c4cab87e09798',
#     'isConnected': True,
#     'connectedAt': '2025-08-25T10:18:42.477Z',
#     'storeName': 'GlobalFlow.ai-ESP',
#     'storeEmail': 'sales@globalflow.ai',
#     'plan': 'Developer Preview',
#     'currencyCode': 'GBP',
#     'submissionStatus': None,
#     'submittedAt': None,
#     '_id': '68adf0a8a2e59d75c778fe55',
# ...
